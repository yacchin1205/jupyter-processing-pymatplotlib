# %%
# %load_ext processingpymat

# %%
# %matplotlib nbagg

# %% [markdown]
# Examples from https://github.com/Abdur-rahmaanJ/ppython

# %%
# %%processing skipframes=4
# def setup():
#     pass
#
# def draw():
#     background(255, 255, 255)
#     for i in range(20):
#         ry = random(2, 10)*10
#         fill(i*10, 100, 20)
#         rect(10 + i*10, 150-ry, 10, ry)
#         fill(255, 0, 0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /srv/conda/envs/notebook/lib/python3.7/site-packages/processingpymat/processing.py:19: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/processingpymat/processing.py:20: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])
# (<processingpymat.processing.Processing at 0x7f5d0269b8d0>,
#  <matplotlib.animation.FuncAnimation at 0x7f5d01c1a410>)

# %%
# %%processing
# def setup():
#     size = 100
#     noStroke()
#
#     fill(245, 80, 35)
#     rect(10, 10, size, size)
#
#     fill(125, 185, 0)
#     rect(120, 10, size, size)
#
#     fill(0, 160, 240)
#     rect(10, 120, size, size)
#
#     fill(255, 185, 0)
#     rect(120, 120, size, size)
#
# def draw():
#     pass
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<processingpymat.processing.Processing at 0x7f5cff1ee910>,
#  <matplotlib.animation.FuncAnimation at 0x7f5cff173e50>)

# %%
# %%processing skipframes=5
# class Particle:
#     def __init__(self, x, y, r=10, vx=1, vy=1, randv=False):
#         self.x = x
#         self.y = y
#         self.r = r
#         self.vx = vx
#         self.vy = vy
#
#         if randv:
#             rand1 = random(0, 1)
#             rand2 = random(0, 1)
#             if rand1 > 0.5:
#                 self.vx *= -1
#             if rand2 > 0.5:
#                 self.vy *= -1
#
#
#     def draw(self):
#         noStroke()
#         fill(140,70,20)
#         ellipse(self.x, self.y, self.r, self.r)
#
#     def update(self):
#         self.x += self.vx
#         self.y += self.vy
#
#     def check_bounds(self):
#         global width
#         if self.x > width-self.r or self.x-self.r < 0:
#             self.vx *= -1
#         if self.y > height-self.r or self.y-self.r < 0:
#             self.vy *= -1
#
#     def run(self):
#         self.update()
#         self.check_bounds()
#         self.draw()
#
# particles = [Particle(
#                 random(0, width), random(0, width), vx=2, vy=2, randv=True)
#             for i in range(200)]
# def setup():
#     pass
#
# def draw():
#     global particles
#     background(255, 255, 255)
#     for p in particles:
#         p.run()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<processingpymat.processing.Processing at 0x7f5cff0fcc90>,
#  <matplotlib.animation.FuncAnimation at 0x7f5cff0d74d0>)

# %%
lastproc = %lastprocess
lastproc.generate(skipframes=0, frames=360, debug=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
# Draw(frame=0): duration=0.193327 seconds.
# Draw(frame=0): duration=0.00752 seconds.
# Draw(frame=1): duration=0.018849 seconds.
# Draw(frame=2): duration=0.008053 seconds.
# Draw(frame=3): duration=0.01073 seconds.
# Draw(frame=67): duration=0.016204 seconds.
# Draw(frame=68): duration=0.005216 seconds.
# Draw(frame=69): duration=0.007942 seconds.
# Draw(frame=70): duration=0.006071 seconds.
# Draw(frame=71): duration=0.00516 seconds.
# Draw(frame=72): duration=0.011182 seconds.
# Draw(frame=73): duration=0.005846 seconds.
# Draw(frame=74): duration=0.008879 seconds.
# Draw(frame=75): duration=0.009947 seconds.
# Draw(frame=76): duration=0.034369 seconds.
# Draw(frame=77): duration=0.007355 seconds.
# Draw(frame=78): duration=0.005424 seconds.
# Draw(frame=79): duration=0.00651 seconds.
# Draw(frame=80): duration=0.008373 seconds.
# Draw(frame=81): duration=0.006324 seconds.
# Draw(frame=82): duration=0.007198 seconds.
# Draw(frame=83): duration=0.004762 seconds.
# Draw(frame=84): duration=0.003934 seconds.
# Draw(frame=85): duration=0.009591 seconds.
# Draw(frame=86): duration=0.008609 seconds.
# Draw(frame=87): duration=0.011972 seconds.
# Draw(frame=88): duration=0.006688 seconds.
# Draw(frame=89): duration=0.007802 seconds.
# Draw(frame=90): duration=0.007577 seconds.
# Draw(frame=91): duration=0.006665 seconds.
# Draw(frame=92): duration=0.006659 seconds.
# Draw(frame=93): duration=0.006158 seconds.
# Draw(frame=94): duration=0.01049 seconds.
# Draw(frame=95): duration=0.017572 seconds.
# Draw(frame=96): duration=0.013894 seconds.
# Draw(frame=97): duration=0.009202 seconds.
# Draw(frame=98): duration=0.006051 seconds.
# Draw(frame=99): duration=0.008909 seconds.
# Draw(frame=100): duration=0.00522 seconds.
# Draw(frame=101): duration=0.014531 seconds.
# Draw(frame=102): duration=0.010112 seconds.
# Draw(frame=103): duration=0.014344 seconds.
# Draw(frame=104): duration=0.007847 seconds.
# Draw(frame=105): duration=0.019028 seconds.
# Draw(frame=106): duration=0.01337 seconds.
# Draw(frame=107): duration=0.010761 seconds.
# Draw(frame=108): duration=0.00585 seconds.
# Draw(frame=109): duration=0.021093 seconds.
# Draw(frame=110): duration=0.0103 seconds.
# Draw(frame=111): duration=0.00668 seconds.
# Draw(frame=112): duration=0.004623 seconds.
# Draw(frame=113): duration=0.012606 seconds.
# Draw(frame=114): duration=0.00701 seconds.
# Draw(frame=115): duration=0.013975 seconds.
# Draw(frame=116): duration=0.016499 seconds.
# Draw(frame=117): duration=0.007604 seconds.
# Draw(frame=118): duration=0.007772 seconds.
# Draw(frame=119): duration=0.008312 seconds.
# Draw(frame=120): duration=0.007051 seconds.
# Draw(frame=121): duration=0.005126 seconds.
# Draw(frame=122): duration=0.005848 seconds.
# Draw(frame=123): duration=0.004173 seconds.
# Draw(frame=124): duration=0.011922 seconds.
# Draw(frame=125): duration=0.008361 seconds.
# Draw(frame=126): duration=0.0125 seconds.
# Draw(frame=127): duration=0.008968 seconds.
# Draw(frame=128): duration=0.006252 seconds.
# Draw(frame=129): duration=0.006965 seconds.
# Draw(frame=319): duration=0.007478 seconds.
# Draw(frame=320): duration=0.012143 seconds.
# Draw(frame=321): duration=0.025859 seconds.
# Draw(frame=322): duration=0.004207 seconds.
# Draw(frame=323): duration=0.035908 seconds.
# Draw(frame=324): duration=0.008734 seconds.
# Draw(frame=325): duration=0.024352 seconds.
# Draw(frame=326): duration=0.008538 seconds.
# Draw(frame=327): duration=0.01105 seconds.
# Draw(frame=328): duration=0.010093 seconds.
# Draw(frame=329): duration=0.00935 seconds.
# Draw(frame=330): duration=0.011634 seconds.
# Draw(frame=331): duration=0.010029 seconds.
# Draw(frame=332): duration=0.024428 seconds.
# Draw(frame=333): duration=0.083889 seconds.
# Draw(frame=334): duration=0.008036 seconds.
# Draw(frame=335): duration=0.011532 seconds.
# Draw(frame=336): duration=0.019712 seconds.
# Draw(frame=337): duration=0.029458 seconds.
# Draw(frame=338): duration=0.013296 seconds.
# Draw(frame=339): duration=0.010732 seconds.
# Draw(frame=340): duration=0.006684 seconds.
# Draw(frame=341): duration=0.012918 seconds.
# Draw(frame=342): duration=0.005296 seconds.
# Draw(frame=343): duration=0.010598 seconds.
# Draw(frame=344): duration=0.012504 seconds.
# Draw(frame=345): duration=0.007408 seconds.
# Draw(frame=346): duration=0.01369 seconds.
# Draw(frame=347): duration=0.009089 seconds.
# Draw(frame=348): duration=0.007754 seconds.
# Draw(frame=349): duration=0.00924 seconds.
# Draw(frame=350): duration=0.00791 seconds.
# Draw(frame=351): duration=0.138885 seconds.
# Draw(frame=352): duration=0.009436 seconds.
# Draw(frame=353): duration=0.007861 seconds.
# Draw(frame=354): duration=0.064221 seconds.
# Draw(frame=355): duration=0.006446 seconds.
# Draw(frame=356): duration=0.007939 seconds.
# Draw(frame=357): duration=0.006925 seconds.
# Draw(frame=358): duration=0.010688 seconds.
# Draw(frame=359): duration=0.005559 seconds.
# <video width="640" height="480" controls autoplay loop>
#   <source type="video/mp4" src="...

# %%
# %%processing
# def triangle(x1, y1, x2, y2, x3, y3):
#     beginShape()
#     vertex(x1, y1)
#     vertex(x2, y2)
#     vertex(x3, y3)
#     endShape()
#
# def setup():
#     background(255)
#     noStroke()
#     for x in range(0, width, 50):
#         for y in range(0, width, 50):
#             fill(random(0, 255), random(0, 255), random(0, 255))
#             triangle(
#                 random(x, x+50),
#                 random(y, y+50),
#                 random(x, x+50),
#                 random(y, y+50),
#                 random(x, x+50),
#                 random(y, y+50)
#                 )
#
# def draw():
#     pass
# Out:
# <img src="data:image/png;base64,..." width="640">
# /srv/conda/envs/notebook/lib/python3.7/site-packages/processingpymat/processing.py:19: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# /srv/conda/envs/notebook/lib/python3.7/site-packages/processingpymat/processing.py:20: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])
# (<processingpymat.processing.Processing at 0x7f5cfee82410>,
#  <matplotlib.animation.FuncAnimation at 0x7f5cfdc31350>)
