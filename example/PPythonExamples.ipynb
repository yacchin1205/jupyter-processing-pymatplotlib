# %%
# %load_ext processingpymat

# %%
# %matplotlib nbagg

# %% [markdown]
# Examples from https://github.com/Abdur-rahmaanJ/ppython

# %%
# %%processing skipframes=4
# def setup():
#     pass
#
# def draw():
#     background(255, 255, 255)
#     for i in range(20):
#         ry = random(2, 10)*10
#         fill(i*10, 100, 20)
#         rect(10 + i*10, 150-ry, 10, ry)
#         fill(255, 0, 0)
# Out:
# <img src="data:image/png;base64,..." width="640">
# /home/yazawasatoshi/processingpymat/processing.py:19: MatplotlibDeprecationWarning: Passing the minor parameter of set_xticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_xticks([], [])
# /home/yazawasatoshi/processingpymat/processing.py:20: MatplotlibDeprecationWarning: Passing the minor parameter of set_yticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   ax.set_yticks([], [])
# (<processingpymat.processing.Processing at 0x7f4783d4fb90>,
#  <matplotlib.animation.FuncAnimation at 0x7f4788249f10>)

# %%
# %%processing
# def setup():
#     size = 100
#     noStroke()
#
#     fill(245, 80, 35)
#     rect(10, 10, size, size)
#
#     fill(125, 185, 0)
#     rect(120, 10, size, size)
#
#     fill(0, 160, 240)
#     rect(10, 120, size, size)
#
#     fill(255, 185, 0)
#     rect(120, 120, size, size)
#
# def draw():
#     pass
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<processingpymat.processing.Processing at 0x7f47a90ee890>,
#  <matplotlib.animation.FuncAnimation at 0x7f47880628d0>)

# %%
# %%processing skipframes=5
# class Particle:
#     def __init__(self, x, y, r=10, vx=1, vy=1, randv=False):
#         self.x = x
#         self.y = y
#         self.r = r
#         self.vx = vx
#         self.vy = vy
#
#         if randv:
#             rand1 = random(0, 1)
#             rand2 = random(0, 1)
#             if rand1 > 0.5:
#                 self.vx *= -1
#             if rand2 > 0.5:
#                 self.vy *= -1
#
#
#     def draw(self):
#         noStroke()
#         fill(140,70,20)
#         ellipse(self.x, self.y, self.r, self.r)
#
#     def update(self):
#         self.x += self.vx
#         self.y += self.vy
#
#     def check_bounds(self):
#         global width
#         if self.x > width-self.r or self.x-self.r < 0:
#             self.vx *= -1
#         if self.y > height-self.r or self.y-self.r < 0:
#             self.vy *= -1
#
#     def run(self):
#         self.update()
#         self.check_bounds()
#         self.draw()
#
# particles = [Particle(
#                 random(0, width), random(0, width), vx=2, vy=2, randv=True)
#             for i in range(200)]
# def setup():
#     pass
#
# def draw():
#     global particles
#     background(255, 255, 255)
#     for p in particles:
#         p.run()
# Out:
# <img src="data:image/png;base64,..." width="640">
# (<processingpymat.processing.Processing at 0x7f4788084f50>,
#  <matplotlib.animation.FuncAnimation at 0x7f4788037d10>)

# %%
lastproc = %lastprocess
lastproc.generate(skipframes=0, frames=360, debug=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-cb0e97b390e3> in <module>
# ----> 1 lastproc = get_ipython().run_line_magic('lastprocess', '')
#       2 lastproc.generate(skipframes=0, frames=360, debug=True)
#
# /srv/conda/envs/notebook/lib/python3.7/site-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# TypeError: lastprocess() takes 1 positional argument but 2 were given
